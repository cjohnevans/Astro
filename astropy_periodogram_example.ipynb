# %%
# example of timeseries analysis using astropy
# get data from kepler
from astropy.utils.data import get_pkg_data_filename
filename = get_pkg_data_filename('timeseries/kplr010666592-2009131110544_slc.fits')
ts = TimeSeries.read(filename, format='kepler.fits')
# Out:
# WARNING: UnitsWarning: 'BJD - 2454833' did not parse as fits unit: At col 0, Unit 'BJD' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'e-/s' did not parse as fits unit: At col 0, Unit 'e' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'pixels' did not parse as fits unit: At col 0, Unit 'pixels' not supported by the FITS standard. Did you mean pixel? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]

# %%
print(ts.time)
# Out:
# ['2009-05-02T00:41:40.338' '2009-05-02T00:42:39.188'
#  '2009-05-02T00:43:38.045' ... '2009-05-11T18:05:14.479'
#  '2009-05-11T18:06:13.328' '2009-05-11T18:07:12.186']

# %%
from astropy.timeseries import TimeSeries
import matplotlib.pyplot as plt

# %%
# plot lightcurve
plt.plot(ts.time.jd, ts['sap_flux'], 'k.', markersize=1)
plt.xlabel('Julian Date')
plt.ylabel('SAP Flux (e-/s)')
# Out:
# Text(0, 0.5, 'SAP Flux (e-/s)')

# %%
import numpy as np
from astropy import units as u
from astropy.timeseries import BoxLeastSquares
periodogram = BoxLeastSquares.from_timeseries(ts, 'sap_flux')

# %%
periodogram

# %%
print(periodogram)
# Out:
# <astropy.timeseries.periodograms.bls.core.BoxLeastSquares object at 0x7fd6982bb100>

# %%
print(periodogram.y[0])
# Out:
# 1027045.0625 electron / s

# %%
plt.plot(periodogram.t, periodogram.y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a real number, not 'Time'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 plt.plot(periodogram.t, periodogram.y)
#
# File ~/miniconda3/envs/astro/lib/python3.10/site-packages/matplotlib/pyplot.py:2769, in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/miniconda3/envs/astro/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1634, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
# -> 1634     self.add_line(line)
#    1635 self._request_autoscale_view(scalex=scalex, scaley=scaley)
#    1636 return lines
#
# File ~/miniconda3/envs/astro/lib/python3.10/site-packages/matplotlib/axes/_base.py:2288, in _AxesBase.add_line(self, line)
#    2285 if line.get_clip_path() is None:
#    2286     line.set_clip_path(self.patch)
# -> 2288 self._update_line_limits(line)
#    2289 if not line.get_label():
#    2290     line.set_label(f'_child{len(self._children)}')
#
# File ~/miniconda3/envs/astro/lib/python3.10/site-packages/matplotlib/axes/_base.py:2311, in _AxesBase._update_line_limits(self, line)
#    2307 def _update_line_limits(self, line):
#    2308     """
#    2309     Figures out the data limit of the given line, updating self.dataLim.
#    2310     """
# -> 2311     path = line.get_path()
#    2312     if path.vertices.size == 0:
#    2313         return
#
# File ~/miniconda3/envs/astro/lib/python3.10/site-packages/matplotlib/lines.py:999, in Line2D.get_path(self)
#     997 """Return the `~matplotlib.path.Path` associated with this line."""
#     998 if self._invalidy or self._invalidx:
# --> 999     self.recache()
#    1000 return self._path
#
# File ~/miniconda3/envs/astro/lib/python3.10/site-packages/matplotlib/lines.py:652, in Line2D.recache(self, always)
#     650 if always or self._invalidx:
#     651     xconv = self.convert_xunits(self._xorig)
# --> 652     x = _to_unmasked_float_array(xconv).ravel()
#     653 else:
#     654     x = self._x
#
# File ~/miniconda3/envs/astro/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1296, in _to_unmasked_float_array(x)
#    1291 """
#    1292 Convert a sequence to a float array; if input was a masked array, masked
#    1293 values are converted to nans.
#    1294 """
#    1295 if hasattr(x, 'mask'):
# -> 1296     return np.ma.asarray(x, float).filled(np.nan)
#    1297 else:
#    1298     return np.asarray(x, float)
#
# File ~/miniconda3/envs/astro/lib/python3.10/site-packages/numpy/ma/core.py:7952, in asarray(a, dtype, order)
#    7908 """
#    7909 Convert the input to a masked array of the given data-type.
#    7910
#    (...)
#    7949
#    7950 """
#    7951 order = order or 'C'
# -> 7952 return masked_array(a, dtype=dtype, copy=False, keep_mask=True,
#    7953                     subok=False, order=order)
#
# File ~/miniconda3/envs/astro/lib/python3.10/site-packages/numpy/ma/core.py:2829, in MaskedArray.__new__(cls, data, mask, dtype, copy, subok, ndmin, fill_value, keep_mask, hard_mask, shrink, order)
#    2820 """
#    2821 Create a new masked array from scratch.
#    2822
#    (...)
#    2826
#    2827 """
#    2828 # Process data.
# -> 2829 _data = np.array(data, dtype=dtype, copy=copy,
#    2830                  order=order, subok=True, ndmin=ndmin)
#    2831 _baseclass = getattr(data, '_baseclass', type(_data))
#    2832 # Check that we're not erasing the mask.
#
# ValueError: setting an array element with a sequence.
