# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
# Betelgeuse
data_path = '/home/john/astro/variable_star_data/baa/ALPHA_ORI_20230704_190708.csv'
data_path = 'C:\\Users\\sapje1\\data\\astro\\ALPHA_ORI_20230705_171757.csv'

# %%
bet = pd.read_csv(data_path)

# %%
bet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4593 entries, 0 to 4592
# Data columns (total 14 columns):
#  #   Column                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                              --------------  -----
#  0   Object                                                                                                              4593 non-null   object
#  1   Julian Date                                                                                                         4593 non-null   float64
#  2   UT                                                                                                                  4593 non-null   object
#  3   Magnitude Qualifier                                                                                                 4593 non-null   object
# ...

# %%
# remove one bad point
bet[bet.Magnitude>4]
# Out:
#         Object   Julian Date                    UT Magnitude Qualifier  \
# 166  ALPHA ORI  2.459610e+06  30 Jan 2022 23:18:00               Equal
#
#      Magnitude  Magnitude Error Observer Name  Method Equipment     Filter  \
# 166        8.2              NaN      R K Hunt  Visual    B10x50  No Filter
#
#     Chart / Sequence Visual Estimates  \
# 166           375.01              F-2
#
#     CCD Measurement Data: Measurement Type;Star Type;Star Id;Measured Mag;Measured Error;Reference Mag;Reference Error  \
# 166                                                NaN
#
#      Observation_Id
# 166         4363242

# %%
bet=bet.drop(166)

# %%
bet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4592 entries, 0 to 4592
# Data columns (total 14 columns):
#  #   Column                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                              --------------  -----
#  0   Object                                                                                                              4592 non-null   object
#  1   Julian Date                                                                                                         4592 non-null   float64
#  2   UT                                                                                                                  4592 non-null   object
#  3   Magnitude Qualifier                                                                                                 4592 non-null   object
# ...

# %%
# convert index to datetime
bet.index = pd.to_datetime(bet.UT)

# %%
bet.head()
# Out:
#                             Object   Julian Date                           UT  \
# UT
# 2023-04-21 20:00:00.000  ALPHA ORI  2.460056e+06         21 Apr 2023 20:00:00
# 2023-04-19 20:10:00.000  ALPHA ORI  2.460054e+06         19 Apr 2023 20:10:00
# 2023-04-18 20:30:00.000  ALPHA ORI  2.460053e+06         18 Apr 2023 20:30:00
# 2023-04-15 20:29:45.600  ALPHA ORI  2.460050e+06  15 Apr 2023 20:29:45.600000
# 2023-04-15 19:49:00.000  ALPHA ORI  2.460050e+06         15 Apr 2023 19:49:00
#
#                         Magnitude Qualifier  Magnitude  Magnitude Error  \
# UT
# 2023-04-21 20:00:00.000               Equal        0.2              NaN
# 2023-04-19 20:10:00.000               Equal        0.1              NaN
# 2023-04-18 20:30:00.000               Equal        0.5              NaN
# 2023-04-15 20:29:45.600               Equal        0.5              NaN
# 2023-04-15 19:49:00.000               Equal        0.1              NaN
#
# ...

# %%
fig,ax = plt.subplots()
bet.Magnitude.plot(ax=ax,linestyle='None',marker='.')
ax.invert_yaxis()

# %%
bet.
